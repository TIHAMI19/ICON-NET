# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_54.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_59.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_45.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_47.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_77.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_50.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_49.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_87.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_46.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_46.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_39.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_39.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_57.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_74.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_54.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_47.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_55.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_80.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_58.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_83.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_68.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_39.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_43.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_57.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_76.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_55.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_60.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_81.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_48.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_66.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_56.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_59.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_84.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_58.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_67.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_42.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_43.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_64.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_61.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_72.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_47.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_52.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_43.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_85.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_55.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_71.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_40.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_49.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_65.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_56.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_39.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_45.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_46.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_56.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_50.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_42.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_79.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_47.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_51.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_48.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_60.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_75.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_58.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_62.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_53.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_48.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_EZ_7264_20010816_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_52.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_6669_20020102_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_40.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_70.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7855_19951020_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_73.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7874_19950902_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_50.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_53.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7605_19950916_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_53.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_A5TP_19970614_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8563_19981209_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7019_19940908_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_8018_19970411_13.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_FG_A4MT_20020212_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_86.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7014_19860618_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4942_19970222_17.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_CS_4941_19960909_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_DU_7010_19860307_48.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7884_19980913_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_7877_19980917_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/test/images/TCGA_HT_A61B_19991127_15.png
# ...
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5853_19950823_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5872_19950223_61.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7643_20021104_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8167_19970402_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_8111_19980330_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_5393_19990606_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7692_19960724_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6186_20000601_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8166_19970322_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5852_19950709_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7306_19930512_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8167_19970402_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6688_20020215_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7693_19950520_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8163_19961119_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7300_19910814_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7879_19981009_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_5962_20000626_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8168_19970503_36.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7881_19981015_59.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_50.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7018_19911220_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6408_19860521_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6665_20010817_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7882_19970125_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6408_19860521_55.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8163_19961119_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5849_19950405_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6408_19860521_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7302_19911203_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8162_19961029_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7013_19860523_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_51.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_4943_20000902_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5851_19950428_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TW_19980228_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6407_19860514_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A616_19991226_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7881_19981015_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6407_19860514_51.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TY_19970709_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8165_19970205_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_A60K_20040224_66.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5872_19950223_51.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7860_19960513_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7680_19970202_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7013_19860523_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7299_19910417_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5871_19941206_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_4944_20010208_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6404_19850629_50.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8164_19970111_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_4.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5851_19950428_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7304_19930325_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A61A_20000127_76.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_8189_20030516_58.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7299_19910417_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7684_19950816_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7602_19951103_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5852_19950709_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7882_19970125_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6188_20010812_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TT_19980318_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7306_19930512_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A61A_20000127_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8163_19961119_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8167_19970402_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6689_20020326_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5855_19951217_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_5962_20000626_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7475_19970918_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6188_20010812_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_5397_20010315_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7301_19911112_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7643_20021104_23.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5853_19950823_35.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_5393_19990606_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7309_19960831_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A616_19991226_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6691_20020405_48.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7008_19830723_39.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7881_19981015_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7309_19960831_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6666_20011109_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7302_19911203_34.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6668_20011025_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5855_19951217_24.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A616_19991226_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5874_19950510_2.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5872_19950223_46.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7008_19830723_27.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5854_19951104_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5855_19951217_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5874_19950510_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_5396_20010302_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7306_19930512_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_5962_20000626_31.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_26.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7299_19910417_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5855_19951217_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7634_20000128_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7298_19910324_5.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7602_19951103_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A61A_20000127_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7856_19950831_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7881_19981015_62.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7856_19950831_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7692_19960724_10.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6186_20000601_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_A60K_20040224_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TW_19980228_19.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7693_19950520_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_8105_19980826_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_8189_20030516_38.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6404_19850629_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_5962_20000626_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_8114_19981030_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_7.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6399_19830416_37.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7881_19981015_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7634_20000128_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_8106_19970727_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7643_20021104_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8165_19970205_30.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A616_19991226_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5872_19950223_21.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_8164_19970111_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7294_19890104_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_8105_19980826_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TY_19970709_3.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_8189_20030516_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6400_19830518_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_7299_19910417_20.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6690_20020226_32.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6688_20020215_25.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7637_20000922_41.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7686_19950629_11.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TS_19970726_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7643_20021104_46.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5874_19950510_9.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_A61A_20000127_67.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6401_19831001_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7686_19950629_1.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_A60K_20040224_28.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TT_19980318_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_CS_6290_20000917_15.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5874_19950510_8.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_5962_20000626_44.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_7643_20021104_12.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TS_19970726_16.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_6407_19860514_14.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7686_19950629_6.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_8189_20030516_18.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_5872_19950223_33.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_FG_6690_20020226_29.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_DU_A5TR_19970726_22.png
# /kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices/train/masks/TCGA_HT_7473_19970826_20.png

# %%
# !pip install torch==2.3.1 torchvision==0.18.1 --index-url https://download.pytorch.org/whl/cu118 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 839.6/839.6 MB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 78.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 42.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 99.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 32.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 14.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.9/142.9 MB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 6.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.10.0+cu128 requires torch==2.10.0, but you have torch 2.3.1+cu118 which is incompatible.

# %%
import subprocess
subprocess.run(["pip", "install", "segmentation-models-pytorch", "einops", "-q"], check=True)

import os, glob, random
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms.functional as TF

torch.manual_seed(42)
random.seed(42)
np.random.seed(42)

BASE_PATH     = "/kaggle/input/datasets/ahmadnafeestihami/lgg2d-slices"
TRAIN_IMG_DIR = os.path.join(BASE_PATH, "train/images")
TRAIN_MSK_DIR = os.path.join(BASE_PATH, "train/masks")
TEST_IMG_DIR  = os.path.join(BASE_PATH, "test/images")
TEST_MSK_DIR  = os.path.join(BASE_PATH, "test/masks")

CFG = dict(
    img_size     = 256,
    batch_size   = 8,
    lr           = 1e-4,
    weight_decay = 1e-5,
    epochs       = 80,
    patience     = 10,
    val_split    = 0.15,
    device       = "cuda" if torch.cuda.is_available() else "cpu",
)
print(f"Device : {CFG['device']}")
print(f"PyTorch: {torch.__version__}")


class BRISCDataset(Dataset):
    def __init__(self, img_paths, mask_paths, img_size=256, augment=False):
        self.img_paths  = img_paths
        self.mask_paths = mask_paths
        self.img_size   = img_size
        self.augment    = augment

    def __len__(self):
        return len(self.img_paths)

    def _load(self, path, gray=False):
        img = Image.open(path).convert("L" if gray else "RGB")
        return img.resize((self.img_size, self.img_size), Image.BILINEAR)

    def __getitem__(self, idx):
        img  = self._load(self.img_paths[idx])
        mask = self._load(self.mask_paths[idx], gray=True)
        if self.augment:
            if random.random() > 0.5: img, mask = TF.hflip(img), TF.hflip(mask)
            if random.random() > 0.5: img, mask = TF.vflip(img), TF.vflip(mask)
            angle = random.choice([0, 90, 180, 270])
            if angle:
                img  = TF.rotate(img,  angle)
                mask = TF.rotate(mask, angle)
            img = TF.adjust_brightness(img, random.uniform(0.8, 1.2))
            img = TF.adjust_contrast(img,   random.uniform(0.8, 1.2))
        img  = TF.to_tensor(img)
        img  = TF.normalize(img, [0.5]*3, [0.5]*3)
        mask = TF.to_tensor(mask)
        mask = (mask > 0.5).float()
        return img, mask


def get_loaders():
    img_paths  = sorted(glob.glob(os.path.join(TRAIN_IMG_DIR, "*")))
    mask_paths = sorted(glob.glob(os.path.join(TRAIN_MSK_DIR, "*")))
    assert len(img_paths) > 0, f"No images found at {TRAIN_IMG_DIR}"
    assert len(img_paths) == len(mask_paths), "Image/mask count mismatch!"
    print(f"Total train samples: {len(img_paths)}")
    idx = list(range(len(img_paths)))
    random.shuffle(idx)
    n_val = int(len(idx) * CFG["val_split"])
    t_idx, v_idx = idx[n_val:], idx[:n_val]
    train_ds = BRISCDataset([img_paths[i] for i in t_idx],
                             [mask_paths[i] for i in t_idx],
                             CFG["img_size"], augment=True)
    val_ds   = BRISCDataset([img_paths[i] for i in v_idx],
                             [mask_paths[i] for i in v_idx],
                             CFG["img_size"], augment=False)
    train_loader = DataLoader(train_ds, batch_size=CFG["batch_size"],
                              shuffle=True,  num_workers=2, pin_memory=True)
    val_loader   = DataLoader(val_ds,   batch_size=CFG["batch_size"],
                              shuffle=False, num_workers=2, pin_memory=True)
    print(f"Train: {len(train_ds)} | Val: {len(val_ds)}")
    return train_loader, val_loader


def get_test_loader():
    img_paths  = sorted(glob.glob(os.path.join(TEST_IMG_DIR, "*")))
    mask_paths = sorted(glob.glob(os.path.join(TEST_MSK_DIR, "*")))
    assert len(img_paths) > 0, f"No test images found at {TEST_IMG_DIR}"
    print(f"Total test samples: {len(img_paths)}")
    test_ds = BRISCDataset(img_paths, mask_paths, CFG["img_size"], augment=False)
    return DataLoader(test_ds, batch_size=CFG["batch_size"],
                      shuffle=False, num_workers=2, pin_memory=True)


class DiceBCELoss(nn.Module):
    def __init__(self, smooth=1.0):
        super().__init__()
        self.smooth = smooth
        self.bce    = nn.BCEWithLogitsLoss()

    def forward(self, logits, targets):
        bce   = self.bce(logits, targets)
        prob  = torch.sigmoid(logits)
        inter = (prob * targets).sum(dim=(2, 3))
        dice  = 1 - (2*inter + self.smooth) / (
                    prob.sum(dim=(2,3)) + targets.sum(dim=(2,3)) + self.smooth)
        return 0.5 * dice.mean() + 0.5 * bce


def compute_metrics(logits, masks, thresh=0.5):
    preds = (torch.sigmoid(logits) > thresh).float()
    inter = (preds * masks).sum()
    dice  = (2*inter + 1) / (preds.sum() + masks.sum() + 1)
    iou   = (inter + 1)   / (preds.sum() + masks.sum() - inter + 1)
    acc   = (preds == masks).float().mean()
    tp    = ((preds==1)&(masks==1)).sum().float()
    tn    = ((preds==0)&(masks==0)).sum().float()
    fp    = ((preds==1)&(masks==0)).sum().float()
    fn    = ((preds==0)&(masks==1)).sum().float()
    prec  = tp / (tp + fp + 1e-7)
    rec   = tp / (tp + fn + 1e-7)
    spec  = tn / (tn + fp + 1e-7)
    pixel_acc = (tp + tn) / (tp + tn + fp + fn + 1e-7)
    return dice.item(), iou.item(), acc.item(), prec.item(), rec.item(), spec.item(), pixel_acc.item()


def evaluate_split(model, loader, device, split_name, compute_extra=False):
    model.eval()
    criterion = DiceBCELoss()
    total_loss = 0.0
    v_dice = v_iou = v_acc = v_prec = v_rec = v_spec = v_pix = 0.0
    all_probs = [] if compute_extra else None
    all_masks = [] if compute_extra else None
    hd95_list = [] if compute_extra else None

    with torch.no_grad():
        for imgs, masks in loader:
            imgs, masks = imgs.to(device), masks.to(device)
            out = model(imgs)
            if out.shape[-2:] != masks.shape[-2:]:
                out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
            total_loss += criterion(out, masks).item()
            d, i, a, p, r, s, px = compute_metrics(out, masks)
            v_dice += d; v_iou += i; v_acc += a
            v_prec += p; v_rec += r; v_spec += s; v_pix += px

            if compute_extra:
                from scipy.ndimage import distance_transform_edt
                probs = torch.sigmoid(out).cpu().numpy()
                gt    = masks.cpu().numpy()
                preds = (probs > 0.5).astype(np.float32)
                all_probs.append(probs.reshape(-1))
                all_masks.append(gt.reshape(-1).astype(np.uint8))
                for b in range(probs.shape[0]):
                    pred_b = preds[b, 0].astype(bool)
                    gt_b   = gt[b, 0].astype(bool)
                    if pred_b.sum() == 0 or gt_b.sum() == 0:
                        hd95_list.append(np.nan)
                        continue
                    dist_pred = distance_transform_edt(~pred_b)
                    dist_gt   = distance_transform_edt(~gt_b)
                    surf_pred = dist_gt[pred_b]
                    surf_gt   = dist_pred[gt_b]
                    hd95_list.append(np.percentile(np.concatenate([surf_pred, surf_gt]), 95))

    n = len(loader)

    if compute_extra:
        from sklearn.metrics import roc_auc_score, average_precision_score
        all_probs_np = np.concatenate(all_probs)
        all_masks_np = np.concatenate(all_masks)
        try:
            auc_roc = roc_auc_score(all_masks_np, all_probs_np)
        except Exception:
            auc_roc = float('nan')
        try:
            auc_pr = average_precision_score(all_masks_np, all_probs_np)
        except Exception:
            auc_pr = float('nan')
        valid_hd95 = [x for x in hd95_list if not np.isnan(x)]
        mean_hd95  = float(np.mean(valid_hd95)) if valid_hd95 else float('nan')
    else:
        auc_roc = auc_pr = mean_hd95 = float('nan')

    print(f"\n{'='*60}")
    print(f"  {split_name} EVALUATION")
    print(f"{'='*60}")
    print(f"  Loss       : {total_loss/n:.4f}")
    print(f"  Dice       : {v_dice/n*100:.2f}%")
    print(f"  IoU        : {v_iou/n*100:.2f}%")
    print(f"  Pixel Acc  : {v_pix/n*100:.2f}%")
    print(f"  Accuracy   : {v_acc/n*100:.2f}%")
    print(f"  Precision  : {v_prec/n*100:.2f}%")
    print(f"  Recall     : {v_rec/n*100:.2f}%")
    print(f"  Specificity: {v_spec/n*100:.2f}%")
    if compute_extra:
        print(f"  HD95       : {mean_hd95:.4f} px")
        print(f"  AUC-ROC    : {auc_roc:.4f}")
        print(f"  AUC-PR     : {auc_pr:.4f}")
    print(f"{'='*60}")

    result = {
        "split":       split_name,
        "loss":        round(total_loss/n, 4),
        "dice":        round(v_dice/n,     4),
        "iou":         round(v_iou/n,      4),
        "pixel_acc":   round(v_pix/n,      4),
        "accuracy":    round(v_acc/n,      4),
        "precision":   round(v_prec/n,     4),
        "recall":      round(v_rec/n,      4),
        "specificity": round(v_spec/n,     4),
        "hd95":        round(mean_hd95,    4) if compute_extra else None,
        "auc_roc":     round(auc_roc,      4) if compute_extra else None,
        "auc_pr":      round(auc_pr,       4) if compute_extra else None,
    }
    return result


def plot_history(history, model_name):
    epochs = range(1, len(history["train_loss"]) + 1)
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Left plot — Model Accuracy
    axes[0].plot(epochs, history["train_acc"], color='steelblue',  linewidth=1.5, label="Training Accuracy")
    axes[0].plot(epochs, history["val_acc"],   color='darkorange', linewidth=1.5, label="Validation Accuracy")
    axes[0].set_title("Model Accuracy")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend(loc="lower right")
    axes[0].grid(True, alpha=0.3)

    # Right plot — Model Loss
    axes[1].plot(epochs, history["train_loss"], color='steelblue',  linewidth=1.5, label="Training Loss")
    axes[1].plot(epochs, history["val_loss"],   color='darkorange', linewidth=1.5, label="Validation Loss")
    axes[1].set_title("Model Loss")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("Loss")
    axes[1].legend(loc="upper right")
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"/kaggle/working/{model_name}_history.png", dpi=150)
    plt.show()
    print(f"Plot saved to /kaggle/working/{model_name}_history.png")


# ── ONLY THIS SECTION CHANGED: UNet replaces MambaUNet ──────────────────────

class ConvBNReLU(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1, bias=False),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
        )

    def forward(self, x):
        return self.block(x)


class UNet(nn.Module):
    def __init__(self, in_ch=3, num_classes=1, base=64):
        super().__init__()
        f = [base, base*2, base*4, base*8, base*16]

        # Encoder
        self.enc1 = ConvBNReLU(in_ch, f[0])
        self.enc2 = ConvBNReLU(f[0],  f[1])
        self.enc3 = ConvBNReLU(f[1],  f[2])
        self.enc4 = ConvBNReLU(f[2],  f[3])
        self.pool = nn.MaxPool2d(2)

        # Bottleneck
        self.bottleneck = ConvBNReLU(f[3], f[4])

        # Decoder
        self.up4  = nn.ConvTranspose2d(f[4], f[3], 2, stride=2)
        self.dec4 = ConvBNReLU(f[3]*2, f[3])

        self.up3  = nn.ConvTranspose2d(f[3], f[2], 2, stride=2)
        self.dec3 = ConvBNReLU(f[2]*2, f[2])

        self.up2  = nn.ConvTranspose2d(f[2], f[1], 2, stride=2)
        self.dec2 = ConvBNReLU(f[1]*2, f[1])

        self.up1  = nn.ConvTranspose2d(f[1], f[0], 2, stride=2)
        self.dec1 = ConvBNReLU(f[0]*2, f[0])

        self.dropout = nn.Dropout2d(0.3)
        self.head    = nn.Conv2d(f[0], num_classes, 1)

    def forward(self, x):
        # Encoder path
        e1 = self.enc1(x)
        e2 = self.enc2(self.pool(e1))
        e3 = self.enc3(self.pool(e2))
        e4 = self.enc4(self.pool(e3))

        # Bottleneck
        b  = self.bottleneck(self.pool(e4))

        # Decoder path with skip connections
        d4 = self.dec4(torch.cat([self.up4(b),  e4], 1))
        d3 = self.dec3(torch.cat([self.up3(d4), e3], 1))
        d2 = self.dec2(torch.cat([self.up2(d3), e2], 1))
        d1 = self.dec1(torch.cat([self.up1(d2), e1], 1))

        return self.head(self.dropout(d1))

# ────────────────────────────────────────────────────────────────────────────


def eval_with_tta(model, loader, device):
    """TTA: avg of original + hflip + vflip + rot90"""
    from sklearn.metrics import roc_auc_score, average_precision_score
    from scipy.ndimage import distance_transform_edt
    model.eval()
    all_probs = []
    all_masks = []
    hd95_list = []
    with torch.no_grad():
        for imgs, masks in loader:
            imgs = imgs.to(device)
            p0  = torch.sigmoid(model(imgs))
            p1  = torch.sigmoid(model(torch.flip(imgs, [3])))
            p2  = torch.sigmoid(model(torch.flip(imgs, [2])))
            p3  = torch.sigmoid(model(torch.rot90(imgs, 1, [2, 3])))
            p1b = torch.flip(p1, [3])
            p2b = torch.flip(p2, [2])
            p3b = torch.rot90(p3, -1, [2, 3])
            avg = (p0 + p1b + p2b + p3b) / 4.0
            probs = avg.cpu().numpy()
            gt    = masks.numpy()
            preds = (probs > 0.5).astype(np.float32)
            all_probs.append(probs.reshape(-1))
            all_masks.append(gt.reshape(-1).astype(np.uint8))
            for b in range(probs.shape[0]):
                pred_b = preds[b, 0].astype(bool)
                gt_b   = gt[b, 0].astype(bool)
                if pred_b.sum() == 0 or gt_b.sum() == 0:
                    hd95_list.append(np.nan)
                    continue
                dist_pred = distance_transform_edt(~pred_b)
                dist_gt   = distance_transform_edt(~gt_b)
                surf_pred = dist_gt[pred_b]
                surf_gt   = dist_pred[gt_b]
                hd95_list.append(np.percentile(np.concatenate([surf_pred, surf_gt]), 95))

    all_probs_np = np.concatenate(all_probs)
    all_masks_np = np.concatenate(all_masks)
    preds_np     = (all_probs_np > 0.5).astype(np.uint8)
    gt_np        = all_masks_np

    tp = np.sum((preds_np==1)&(gt_np==1)); tn = np.sum((preds_np==0)&(gt_np==0))
    fp = np.sum((preds_np==1)&(gt_np==0)); fn = np.sum((preds_np==0)&(gt_np==1))
    s  = 1e-7
    dice = (2*tp+s)/(2*tp+fp+fn+s)
    iou  = (tp+s)/(tp+fp+fn+s)
    acc  = (tp+tn+s)/(tp+tn+fp+fn+s)
    prec = (tp+s)/(tp+fp+s)
    rec  = (tp+s)/(tp+fn+s)
    spec = (tn+s)/(tn+fp+s)
    try:    auc_roc = roc_auc_score(gt_np, all_probs_np)
    except: auc_roc = float('nan')
    try:    auc_pr  = average_precision_score(gt_np, all_probs_np)
    except: auc_pr  = float('nan')
    valid_hd95 = [x for x in hd95_list if not np.isnan(x)]
    mean_hd95  = float(np.mean(valid_hd95)) if valid_hd95 else float('nan')

    print(f"\n{'='*60}")
    print(f"  TEST EVALUATION (TTA)")
    print(f"{'='*60}")
    print(f"  Dice       : {dice*100:.2f}%")
    print(f"  IoU        : {iou*100:.2f}%")
    print(f"  Accuracy   : {acc*100:.2f}%")
    print(f"  Precision  : {prec*100:.2f}%")
    print(f"  Recall     : {rec*100:.2f}%")
    print(f"  Specificity: {spec*100:.2f}%")
    print(f"  HD95       : {mean_hd95:.4f} px")
    print(f"  AUC-ROC    : {auc_roc:.4f}")
    print(f"  AUC-PR     : {auc_pr:.4f}")
    print(f"{'='*60}")

    return {
        "split":       "TEST_TTA",
        "loss":        None,
        "dice":        round(dice,      4),
        "iou":         round(iou,       4),
        "pixel_acc":   None,
        "accuracy":    round(acc,       4),
        "precision":   round(prec,      4),
        "recall":      round(rec,       4),
        "specificity": round(spec,      4),
        "hd95":        round(mean_hd95, 4),
        "auc_roc":     round(auc_roc,   4),
        "auc_pr":      round(auc_pr,    4),
    }


def train_model(model, model_name):
    device = CFG["device"]
    model  = model.to(device)

    train_loader, val_loader = get_loaders()
    criterion = DiceBCELoss()
    optimizer = torch.optim.AdamW(model.parameters(),
                                  lr=CFG["lr"],
                                  weight_decay=CFG["weight_decay"])
    scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10)

    best_dice, no_improve = 0.0, 0
    best_weights = None
    history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

    n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print(f"\n{'='*60}")
    print(f"  Model  : {model_name}")
    print(f"  Params : {n_params/1e6:.2f}M")
    print(f"  Device : {device}")
    print(f"{'='*60}")

    for epoch in range(1, CFG["epochs"] + 1):
        model.train()
        t_loss = 0.0
        t_acc  = 0.0
        for imgs, masks in train_loader:
            imgs, masks = imgs.to(device), masks.to(device)
            optimizer.zero_grad()
            out = model(imgs)
            if out.shape[-2:] != masks.shape[-2:]:
                out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
            loss = criterion(out, masks)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            t_loss += loss.item()
            _, _, a, _, _, _, _ = compute_metrics(out, masks)
            t_acc += a
        t_loss /= len(train_loader)
        t_acc  /= len(train_loader)

        model.eval()
        v_loss = 0.0
        v_dice = v_iou = v_acc = v_prec = v_rec = v_spec = v_pix = 0.0
        with torch.no_grad():
            for imgs, masks in val_loader:
                imgs, masks = imgs.to(device), masks.to(device)
                out = model(imgs)
                if out.shape[-2:] != masks.shape[-2:]:
                    out = F.interpolate(out, size=masks.shape[-2:], mode='bilinear', align_corners=False)
                v_loss += criterion(out, masks).item()
                d, i, a, p, r, s, px = compute_metrics(out, masks)
                v_dice += d; v_iou += i; v_acc += a
                v_prec += p; v_rec += r; v_spec += s; v_pix += px

        n = len(val_loader)
        v_loss /= n
        v_dice /= n; v_iou /= n; v_acc /= n
        v_prec /= n; v_rec /= n; v_spec /= n; v_pix /= n

        scheduler.step()
        history["train_loss"].append(t_loss)
        history["val_loss"].append(v_loss)
        history["train_acc"].append(t_acc)
        history["val_acc"].append(v_acc)

        if epoch % 10 == 0 or epoch == 1:
            print(f"  Ep {epoch:03d} | Loss:{t_loss:.4f} | "
                  f"Dice:{v_dice:.4f} | IoU:{v_iou:.4f} | "
                  f"PixAcc:{v_pix:.4f} | Acc:{v_acc:.4f} | "
                  f"Prec:{v_prec:.4f} | Rec:{v_rec:.4f} | Spec:{v_spec:.4f}")

        if v_dice > best_dice:
            best_dice    = v_dice
            best_weights = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            no_improve   = 0
        else:
            no_improve += 1
            if no_improve >= CFG["patience"]:
                print(f"  Early stop at epoch {epoch}.")
                break

    model.load_state_dict(best_weights)

    print(f"\n{'='*60}")
    print(f"  {model_name} TRAINING COMPLETE")
    print(f"  Best Val Dice : {best_dice*100:.2f}%")
    print(f"{'='*60}")

    plot_history(history, model_name)

    print("\n--- Evaluating on Train Set ---")
    train_loader_eval, _ = get_loaders()
    train_metrics = evaluate_split(model, train_loader_eval, device, "TRAIN", compute_extra=False)

    print("\n--- Evaluating on Validation Set ---")
    _, val_loader_eval = get_loaders()
    val_metrics = evaluate_split(model, val_loader_eval, device, "VALIDATION", compute_extra=False)

    print("\n--- Evaluating on Test Set ---")
    test_loader = get_test_loader()
    test_metrics = evaluate_split(model, test_loader, device, "TEST", compute_extra=True)

    # ── TTA test eval ────────────────────────────────────────────────────────
    print("\n--- Evaluating on Test Set (TTA) ---")
    test_loader_tta = get_test_loader()
    tta_metrics = eval_with_tta(model, test_loader_tta, device)

    # ── Save model weights ──────────────────────────────────────────────────
    model_path = f"/kaggle/working/{model_name}_best.pth"
    torch.save(model.state_dict(), model_path)
    print(f"\nModel saved → {model_path}")

    # ── Export metrics CSV ──────────────────────────────────────────────────
    import pandas as pd
    rows = [train_metrics, val_metrics, test_metrics, tta_metrics]
    metrics_df = pd.DataFrame(rows)
    csv_path = f"/kaggle/working/{model_name}_metrics.csv"
    metrics_df.to_csv(csv_path, index=False)
    print(f"Metrics CSV saved → {csv_path}")
    print(metrics_df.to_string(index=False))

    return model, history, best_dice, test_metrics["iou"], model_path, csv_path


model_unet = UNet(in_ch=3, num_classes=1, base=64)
model_unet, history_unet, dice_unet, iou_unet, model_path_model_unet, csv_path_model_unet = train_model(model_unet, "UNet")
print(f"\n[FINAL RESULT] UNet → Val Dice: {dice_unet*100:.2f}% | Test IoU: {iou_unet*100:.2f}%")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.8 MB/s eta 0:00:00
# Device : cuda
# PyTorch: 2.3.1+cu118
# Total train samples: 3342
# Train: 2841 | Val: 501
#
# ============================================================
#   Model  : UNet
#   Params : 31.04M
#   Device : cuda
# ============================================================
#   Ep 001 | Loss:0.6366 | Dice:0.5598 | IoU:0.4214 | PixAcc:0.9884 | Acc:0.9884 | Prec:0.5111 | Rec:0.6666 | Spec:0.9917
#   Ep 010 | Loss:0.4024 | Dice:0.8048 | IoU:0.6892 | PixAcc:0.9962 | Acc:0.9962 | Prec:0.7566 | Rec:0.8787 | Spec:0.9973
#   Ep 020 | Loss:0.2827 | Dice:0.8499 | IoU:0.7543 | PixAcc:0.9972 | Acc:0.9972 | Prec:0.8395 | Rec:0.8719 | Spec:0.9984
#   Ep 030 | Loss:0.0637 | Dice:0.8680 | IoU:0.7747 | PixAcc:0.9974 | Acc:0.9974 | Prec:0.8773 | Rec:0.8405 | Spec:0.9989
#   Early stop at epoch 39.
#
# ============================================================
#   UNet TRAINING COMPLETE
#   Best Val Dice : 87.11%
# ============================================================
# Plot saved to /kaggle/working/UNet_history.png
#
# --- Evaluating on Train Set ---
# Total train samples: 3342
# Train: 2841 | Val: 501
#
# ============================================================
#   TRAIN EVALUATION
# ============================================================
#   Loss       : 0.0489
#   Dice       : 86.86%
#   IoU        : 78.35%
#   Pixel Acc  : 99.77%
#   Accuracy   : 99.77%
#   Precision  : 84.54%
#   Recall     : 83.75%
#   Specificity: 99.89%
# ============================================================
#
# --- Evaluating on Validation Set ---
# Total train samples: 3342
# Train: 2841 | Val: 501
#
# ============================================================
#   VALIDATION EVALUATION
# ============================================================
#   Loss       : 0.0413
#   Dice       : 86.71%
#   IoU        : 78.86%
#   Pixel Acc  : 99.80%
#   Accuracy   : 99.80%
#   Precision  : 82.10%
#   Recall     : 81.91%
#   Specificity: 99.91%
# ============================================================
#
# --- Evaluating on Test Set ---
# Total test samples: 587
#
# ============================================================
#   TEST EVALUATION
# ============================================================
#   Loss       : 0.0514
#   Dice       : 86.19%
#   IoU        : 80.34%
#   Pixel Acc  : 99.75%
#   Accuracy   : 99.75%
#   Precision  : 51.33%
#   Recall     : 47.33%
#   Specificity: 99.89%
#   HD95       : 3.8212 px
#   AUC-ROC    : 0.9900
#   AUC-PR     : 0.9271
# ============================================================
#
# --- Evaluating on Test Set (TTA) ---
# Total test samples: 587
#
# ============================================================
#   TEST EVALUATION (TTA)
# ============================================================
#   Dice       : 87.66%
#   IoU        : 78.03%
#   Accuracy   : 99.76%
#   Precision  : 89.82%
#   Recall     : 85.61%
#   Specificity: 99.90%
#   HD95       : 3.4774 px
#   AUC-ROC    : 0.9925
#   AUC-PR     : 0.9330
# ============================================================
#
# Model saved → /kaggle/working/UNet_best.pth
# Metrics CSV saved → /kaggle/working/UNet_metrics.csv
#      split   loss   dice    iou  pixel_acc  accuracy  precision  recall  specificity   hd95  auc_roc  auc_pr
#      TRAIN 0.0489 0.8686 0.7835     0.9977    0.9977     0.8454  0.8375       0.9989    NaN      NaN     NaN
# VALIDATION 0.0413 0.8671 0.7886     0.9980    0.9980     0.8210  0.8191       0.9991    NaN      NaN     NaN
#       TEST 0.0514 0.8619 0.8034     0.9975    0.9975     0.5133  0.4733       0.9989 3.8212   0.9900  0.9271
#   TEST_TTA    NaN 0.8766 0.7803        NaN    0.9976     0.8982  0.8561       0.9990 3.4774   0.9925  0.9330
#
# [FINAL RESULT] UNet → Val Dice: 87.11% | Test IoU: 80.34%
